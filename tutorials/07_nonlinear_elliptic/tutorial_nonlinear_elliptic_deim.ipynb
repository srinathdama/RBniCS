# %% [markdown]
# ## Tutorial 07 - Non linear Elliptic problem
# **_Keywords: DEIM, POD-Galerkin_**
#
# ### 1. Introduction
#
# In this tutorial, we consider a non linear elliptic problem in a two-dimensional spatial domain $\Omega=(0,1)^2$. We impose a homogeneous Dirichlet condition on the boundary $\partial\Omega$. The source term is characterized by the following expression
# $$
# g(\boldsymbol{x}; \boldsymbol{\mu}) = 100\sin(2\pi x_0)cos(2\pi x_1) \quad \forall \boldsymbol{x} = (x_0, x_1) \in \Omega.
# $$
#
# This problem is characterized by two parameters. The first parameter $\mu_0$ controls the strength of the sink term and the second parameter $\mu_1$ the strength of the nonlinearity. The range of the two parameters is the following:
# $$
# \mu_0,\mu_1\in[0.01,10.0]
# $$
# The parameter vector $\boldsymbol{\mu}$ is thus given by
# $$
# \boldsymbol{\mu} = (\mu_0,\mu_1)
# $$
# on the parameter domain
# $$
# \mathbb{P}=[0.01,10]^2.
# $$
#
#
# In order to obtain a faster approximation of the problem, we pursue a model reduction by means of a POD-Galerkin reduced order method. In order to preserve the affinity assumption the discrete empirical interpolation method will be used on the forcing term $g(\boldsymbol{x}; \boldsymbol{\mu})$.

# %% [markdown]
# ### 2. Parametrized formulation
#
# Let $u(\boldsymbol{\mu})$ be the solution in the domain $\Omega$.
#
# The strong formulation of the parametrized problem is given by:
# <center>for a given parameter $\boldsymbol{\mu}\in\mathbb{P}$, find $u(\boldsymbol{\mu})$ such that</center>
#
# $$ -\nabla^2u(\boldsymbol{\mu})+\frac{\mu_0}{\mu_1}(\exp\{\mu_1u(\boldsymbol{\mu})\}-1)=g(\boldsymbol{x}; \boldsymbol{\mu})$$
# <br>
#
# The corresponding weak formulation reads:
# <center>for a given parameter $\boldsymbol{\mu}\in\mathbb{P}$, find $u(\boldsymbol{\mu})\in\mathbb{V}$ such that</center>
#
# $$a\left(u(\boldsymbol{\mu}),v;\boldsymbol{\mu}\right)+c\left(u(\boldsymbol{\mu}),v;\boldsymbol{\mu}\right)=f(v;\boldsymbol{\mu})\quad \forall v\in\mathbb{V}$$
#
# where
#
# * the function space $\mathbb{V}$ is defined as
# $$
# \mathbb{V} = \{v\in H_1(\Omega) : v|_{\partial\Omega}=0\}
# $$
# * the parametrized bilinear form $a(\cdot, \cdot; \boldsymbol{\mu}): \mathbb{V} \times \mathbb{V} \to \mathbb{R}$ is defined by
# $$a(u, v;\boldsymbol{\mu})=\int_{\Omega} \nabla u\cdot \nabla v \ d\boldsymbol{x},$$
# * the parametrized bilinear form $c(\cdot, \cdot; \boldsymbol{\mu}): \mathbb{V} \times \mathbb{V} \to \mathbb{R}$ is defined by
# $$c(u, v;\boldsymbol{\mu})=\mu_0\int_{\Omega} \frac{1}{\mu_1}\big(\exp\{\mu_1u\} - 1\big)v \ d\boldsymbol{x},$$
# * the parametrized linear form $f(\cdot; \boldsymbol{\mu}): \mathbb{V} \to \mathbb{R}$ is defined by
# $$f(v; \boldsymbol{\mu})= \int_{\Omega}g(\boldsymbol{x}; \boldsymbol{\mu})v \ d\boldsymbol{x}.$$
#
# The output of interest $s(\boldsymbol{\mu})$ is given by
# $$s(\boldsymbol{\mu}) = \int_{\Omega} v \ d\boldsymbol{x}$$
# is computed for each $\boldsymbol{\mu}$.

# %%
from dolfin import *
from rbnics import *

# %% [markdown]
# ### 3. Affine Decomposition
#
# For this problem the affine decomposition is straightforward:
# $$a(u,v;\boldsymbol{\mu})=\underbrace{1}_{\Theta^{a}_0(\boldsymbol{\mu})}\underbrace{\int_{\Omega}\nabla u \cdot \nabla v \ d\boldsymbol{x}}_{a_0(u,v)},$$
# $$c(u,v;\boldsymbol{\mu})=\underbrace{\mu_0}_{\Theta^{c}_0(\boldsymbol{\mu})}\underbrace{\int_{\Omega}\frac{1}{\mu_1}\big(\exp\{\mu_1u\} - 1\big)v \ d\boldsymbol{x}}_{c_0(u,v)},$$
# $$f(v; \boldsymbol{\mu}) = \underbrace{100}_{\Theta^{f}_0(\boldsymbol{\mu})} \underbrace{\int_{\Omega}\sin(2\pi x_0)cos(2\pi x_1)v \ d\boldsymbol{x}}_{f_0(v)}.$$
# We will implement the numerical discretization of the problem in the class
# ```
# class NonlinearElliptic(NonlinearEllipticProblem):
# ```
# by specifying the coefficients $\Theta^{a}_*(\boldsymbol{\mu})$, $\Theta^{c}_*(\boldsymbol{\mu})$ and $\Theta^{f}_*(\boldsymbol{\mu})$ in the method
# ```
#     def compute_theta(self, term):
# ```
# and the bilinear forms $a_*(u, v)$, $c_*(u, v)$ and linear forms $f_*(v)$ in
# ```
#     def assemble_operator(self, term):
# ```

# %%
@DEIM("online", basis_generation="Greedy")
@ExactParametrizedFunctions("offline")
class NonlinearElliptic(NonlinearEllipticProblem):

    # Default initialization of members
    def __init__(self, V, **kwargs):
        # Call the standard initialization
        NonlinearEllipticProblem.__init__(self, V, **kwargs)
        # ... and also store FEniCS data structures for assembly
        assert "subdomains" in kwargs
        assert "boundaries" in kwargs
        self.subdomains, self.boundaries = kwargs["subdomains"], kwargs["boundaries"]
        self.du = TrialFunction(V)
        self.u = self._solution
        self.v = TestFunction(V)
        self.dx = Measure("dx")(subdomain_data=self.subdomains)
        self.ds = Measure("ds")(subdomain_data=self.boundaries)
        # Store the forcing term expression
        self.f = Expression("sin(2*pi*x[0])*sin(2*pi*x[1])", element=self.V.ufl_element())
        # Customize nonlinear solver parameters
        self._nonlinear_solver_parameters.update({
            "linear_solver": "mumps",
            "maximum_iterations": 20,
            "report": True
        })

    # Return custom problem name
    def name(self):
        return "NonlinearEllipticDEIM"

    # Return theta multiplicative terms of the affine expansion of the problem.
    @compute_theta_for_derivatives
    def compute_theta(self, term):
        mu = self.mu
        if term == "a":
            theta_a0 = 1.
            return (theta_a0,)
        elif term == "c":
            theta_c0 = mu[0]
            return (theta_c0,)
        elif term == "f":
            theta_f0 = 100.
            return (theta_f0,)
        elif term == "s":
            theta_s0 = 1.0
            return (theta_s0,)
        else:
            raise ValueError("Invalid term for compute_theta().")

    # Return forms resulting from the discretization of the affine expansion of the problem operators.
    @assemble_operator_for_derivatives
    def assemble_operator(self, term):
        v = self.v
        dx = self.dx
        if term == "a":
            du = self.du
            a0 = inner(grad(du), grad(v)) * dx
            return (a0,)
        elif term == "c":
            u = self.u
            mu = self.mu
            c0 = (exp(mu[1] * u) - 1) / mu[1] * v * dx
            return (c0,)
        elif term == "f":
            f = self.f
            f0 = f * v * dx
            return (f0,)
        elif term == "s":
            s0 = v * dx
            return (s0,)
        elif term == "dirichlet_bc":
            bc0 = [DirichletBC(self.V, Constant(0.0), self.boundaries, 1)]
            return (bc0,)
        elif term == "inner_product":
            du = self.du
            x0 = inner(grad(du), grad(v)) * dx
            return (x0,)
        else:
            raise ValueError("Invalid term for assemble_operator().")


# Customize the resulting reduced problem
@CustomizeReducedProblemFor(NonlinearEllipticProblem)
def CustomizeReducedNonlinearElliptic(ReducedNonlinearElliptic_Base):
    class ReducedNonlinearElliptic(ReducedNonlinearElliptic_Base):
        def __init__(self, truth_problem, **kwargs):
            ReducedNonlinearElliptic_Base.__init__(self, truth_problem, **kwargs)
            self._nonlinear_solver_parameters.update({
                "report": True,
                "line_search": "wolfe"
            })

    return ReducedNonlinearElliptic

# %% [markdown]
# ## 4. Main program
#
# ### 4.1. Read the mesh for this problem
# The mesh was generated by the [data/generate_mesh.ipynb](data/generate_mesh.ipynb) notebook.

# %%
mesh = Mesh("data/square.xml")
subdomains = MeshFunction("size_t", mesh, "data/square_physical_region.xml")
boundaries = MeshFunction("size_t", mesh, "data/square_facet_region.xml")

# %% [markdown]
# ### 4.2. Create Finite Element space (Lagrange P1)

# %%
V = FunctionSpace(mesh, "Lagrange", 1)

# %% [markdown]
# ### 4.3. Allocate an object of the NonlinearElliptic class

# %%
problem = NonlinearElliptic(V, subdomains=subdomains, boundaries=boundaries)
mu_range = [(0.01, 10.0), (0.01, 10.0)]
problem.set_mu_range(mu_range)

# %% [markdown]
# ### 4.4. Prepare reduction with a POD-Galerkin method

# %%
reduction_method = PODGalerkin(problem)
reduction_method.set_Nmax(20, DEIM=21)
reduction_method.set_tolerance(1e-8, DEIM=1e-4)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %% [markdown]
# ### 4.5. Perform the offline phase

# %%
reduction_method.initialize_training_set(50, DEIM=60)
reduced_problem = reduction_method.offline()
# Out:
# ================================================================================
# =                     DEIM preprocessing phase begins for                      =
# =   { v_0 * (-1 + exp(f_9 * f_14)) / f_14 } * dx(<Mesh #0>[everywhere], {}),   =
# =                                    where                                     =
# =                                 f_14 = mu_1                                  =
# =f_9 = solution of NonlinearEllipticDEIM (exact problem decorator: False, component: (None,))=
# =               with id 49fc90be369b6ead57691b159f98bb7ecf8d1031               =
# ================================================================================
#
# :::::::::::::::::::::::::::::::::::: DEIM 0 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.9415867058053458, 7.6843478690549265)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.359042e+00
#   2 SNES Function norm 1.221701e+00
#   3 SNES Function norm 1.097487e+00
#   4 SNES Function norm 9.854588e-01
#   5 SNES Function norm 7.492808e-01
#   6 SNES Function norm 4.679661e-01
#   7 SNES Function norm 9.243486e-02
#   8 SNES Function norm 5.404048e-03
#   9 SNES Function norm 2.018954e-05
#   10 SNES Function norm 2.794084e-10
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 1 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.442763537998275, 2.2426201281897793)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 8.547250e-02
#   2 SNES Function norm 2.213813e-03
#   3 SNES Function norm 1.390837e-06
#   4 SNES Function norm 5.481668e-13
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 2 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (0.2969488703196016, 6.385801888346545)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 5.837511e-01
#   2 SNES Function norm 1.618348e-01
#   3 SNES Function norm 1.855559e-02
#   4 SNES Function norm 2.770813e-04
#   5 SNES Function norm 6.390527e-08
#   6 SNES Function norm 5.326109e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 3 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (5.197366794035331, 8.629468576046566)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358511e+00
#   2 SNES Function norm 1.220014e+00
#   3 SNES Function norm 1.094686e+00
#   4 SNES Function norm 9.820242e-01
#   5 SNES Function norm 7.274975e-01
#   6 SNES Function norm 3.524459e-01
#   7 SNES Function norm 5.602958e-02
#   8 SNES Function norm 1.990472e-03
#   9 SNES Function norm 2.630026e-06
#   10 SNES Function norm 4.490704e-12
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 4 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (6.7202016628275025, 5.939614521733244)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358928e+00
#   2 SNES Function norm 1.146471e+00
#   3 SNES Function norm 6.849675e-01
#   4 SNES Function norm 1.737957e-01
#   5 SNES Function norm 1.647057e-02
#   6 SNES Function norm 1.705503e-04
#   7 SNES Function norm 1.812431e-08
#   8 SNES Function norm 3.903056e-15
# PETSc SNES solver converged in 8 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 5 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.508020583150849, 1.8660088614288413)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.563756e-01
#   2 SNES Function norm 7.030013e-03
#   3 SNES Function norm 1.539330e-05
#   4 SNES Function norm 7.539163e-11
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 6 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.952461951465306, 5.464222673484528)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.299326e+00
#   2 SNES Function norm 8.758627e-01
#   3 SNES Function norm 3.684094e-01
#   4 SNES Function norm 5.812839e-02
#   5 SNES Function norm 1.911256e-03
#   6 SNES Function norm 2.144307e-06
#   7 SNES Function norm 2.683188e-12
# PETSc SNES solver converged in 7 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 7 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (9.765988689889575, 0.46055280628427153)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 3.269308e-02
#   2 SNES Function norm 5.264668e-05
#   3 SNES Function norm 2.804238e-10
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 8 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.288457784184084, 2.7803989785522196)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 3.733508e-01
#   2 SNES Function norm 5.229175e-02
#   3 SNES Function norm 1.181210e-03
#   4 SNES Function norm 6.132988e-07
#   5 SNES Function norm 1.671731e-13
# PETSc SNES solver converged in 5 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: DEIM 9 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (0.33788297859246263, 4.682604078352701)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.238710e-01
#   2 SNES Function norm 1.054269e-02
#   3 SNES Function norm 6.503065e-05
#   4 SNES Function norm 2.412117e-09
#   5 SNES Function norm 4.405597e-15
# PETSc SNES solver converged in 5 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 10 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.246485574651836, 0.5697202072410505)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.134440e-02
#   2 SNES Function norm 3.527681e-06
#   3 SNES Function norm 6.803544e-13
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 11 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (5.552893732555567, 2.397744185207479)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.991752e-01
#   2 SNES Function norm 1.488324e-02
#   3 SNES Function norm 8.432625e-05
#   4 SNES Function norm 2.713663e-09
#   5 SNES Function norm 4.151242e-15
# PETSc SNES solver converged in 5 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 12 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.015937654140149, 8.709321654142771)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358697e+00
#   2 SNES Function norm 1.220503e+00
#   3 SNES Function norm 1.095348e+00
#   4 SNES Function norm 9.826755e-01
#   5 SNES Function norm 7.846810e-01
#   6 SNES Function norm 5.657857e-01
#   7 SNES Function norm 1.186806e-01
#   8 SNES Function norm 8.351608e-03
#   9 SNES Function norm 4.675385e-05
#   10 SNES Function norm 1.448971e-09
#   11 SNES Function norm 4.014468e-15
# PETSc SNES solver converged in 11 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 13 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (9.518017768865464, 7.053662672016322)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358439e+00
#   2 SNES Function norm 1.220299e+00
#   3 SNES Function norm 1.077081e+00
#   4 SNES Function norm 7.068349e-01
#   5 SNES Function norm 2.130827e-01
#   6 SNES Function norm 2.299053e-02
#   7 SNES Function norm 3.266550e-04
#   8 SNES Function norm 6.576154e-08
#   9 SNES Function norm 4.727101e-15
# PETSc SNES solver converged in 9 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 14 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.3503090839090977, 4.483340624912577)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 8.394833e-01
#   2 SNES Function norm 2.308210e-01
#   3 SNES Function norm 2.727893e-02
#   4 SNES Function norm 4.411125e-04
#   5 SNES Function norm 1.193932e-07
#   6 SNES Function norm 9.648930e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 15 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.139657513767789, 5.3829577685291)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 8.796057e-01
#   2 SNES Function norm 3.961552e-01
#   3 SNES Function norm 7.290726e-02
#   4 SNES Function norm 3.289035e-03
#   5 SNES Function norm 7.093787e-06
#   6 SNES Function norm 3.321205e-11
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 16 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.668083125315975, 4.600792920073519)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 7.847465e-01
#   2 SNES Function norm 1.667786e-01
#   3 SNES Function norm 1.449319e-02
#   4 SNES Function norm 1.214163e-04
#   5 SNES Function norm 8.469251e-09
#   6 SNES Function norm 4.054937e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 17 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.182784291171007, 9.131963310071164)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.359007e+00
#   2 SNES Function norm 1.221413e+00
#   3 SNES Function norm 1.096688e+00
#   4 SNES Function norm 9.840534e-01
#   5 SNES Function norm 8.828607e-01
#   6 SNES Function norm 6.339857e-01
#   7 SNES Function norm 2.704999e-01
#   8 SNES Function norm 3.849006e-02
#   9 SNES Function norm 1.042899e-03
#   10 SNES Function norm 7.841618e-07
#   11 SNES Function norm 4.326012e-13
# PETSc SNES solver converged in 11 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 18 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (0.9927386233983351, 3.2560464255476895)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 9.297639e-02
#   2 SNES Function norm 3.960113e-03
#   3 SNES Function norm 6.054302e-06
#   4 SNES Function norm 1.386054e-11
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 19 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.7891798583224245, 2.258559255090893)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 6.511826e-02
#   2 SNES Function norm 1.148483e-03
#   3 SNES Function norm 3.298726e-07
#   4 SNES Function norm 2.745711e-14
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 20 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (9.092074906507335, 0.3610650348335757)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.397018e-02
#   2 SNES Function norm 2.100338e-05
#   3 SNES Function norm 3.532928e-11
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 21 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.4194190042177859, 1.62177818479559)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.836928e-02
#   2 SNES Function norm 9.258609e-05
#   3 SNES Function norm 1.066047e-09
#   4 SNES Function norm 4.836363e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 22 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.349343041992758, 5.690041353707548)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.336798e+00
#   2 SNES Function norm 1.032003e+00
#   3 SNES Function norm 8.245466e-01
#   4 SNES Function norm 2.042501e-01
#   5 SNES Function norm 2.067986e-02
#   6 SNES Function norm 2.508358e-04
#   7 SNES Function norm 3.764211e-08
#   8 SNES Function norm 4.084887e-15
# PETSc SNES solver converged in 8 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 23 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.0697784464770845, 9.429103523687761)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358998e+00
#   2 SNES Function norm 1.221349e+00
#   3 SNES Function norm 1.096503e+00
#   4 SNES Function norm 9.837289e-01
#   5 SNES Function norm 8.824392e-01
#   6 SNES Function norm 6.539277e-01
#   7 SNES Function norm 3.180495e-01
#   8 SNES Function norm 5.011540e-02
#   9 SNES Function norm 1.738562e-03
#   10 SNES Function norm 2.181890e-06
#   11 SNES Function norm 3.355543e-12
# PETSc SNES solver converged in 11 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 24 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.517837609979964, 6.966225355125102)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358546e+00
#   2 SNES Function norm 1.220537e+00
#   3 SNES Function norm 1.076128e+00
#   4 SNES Function norm 7.132499e-01
#   5 SNES Function norm 2.291010e-01
#   6 SNES Function norm 2.635100e-02
#   7 SNES Function norm 4.310709e-04
#   8 SNES Function norm 1.155599e-07
#   9 SNES Function norm 8.992718e-15
# PETSc SNES solver converged in 9 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 25 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.284392111439398, 5.187712819528073)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 9.148910e-01
#   2 SNES Function norm 4.111327e-01
#   3 SNES Function norm 7.498747e-02
#   4 SNES Function norm 3.333423e-03
#   5 SNES Function norm 6.978559e-06
#   6 SNES Function norm 3.076624e-11
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 26 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (9.361784781017985, 4.889994300901736)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.054289e+00
#   2 SNES Function norm 5.845322e-01
#   3 SNES Function norm 1.206101e-01
#   4 SNES Function norm 7.459384e-03
#   5 SNES Function norm 3.121288e-05
#   6 SNES Function norm 5.501899e-10
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 27 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.3203899115006, 6.12431777335316)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358846e+00
#   2 SNES Function norm 1.197038e+00
#   3 SNES Function norm 8.657894e-01
#   4 SNES Function norm 4.635624e-01
#   5 SNES Function norm 8.598539e-02
#   6 SNES Function norm 4.223721e-03
#   7 SNES Function norm 1.091966e-05
#   8 SNES Function norm 7.260693e-11
# PETSc SNES solver converged in 8 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 28 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.13048084609931, 1.7256865922784888)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.318044e-01
#   2 SNES Function norm 4.510367e-03
#   3 SNES Function norm 5.828656e-06
#   4 SNES Function norm 1.000810e-11
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 29 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.966379008534007, 4.067234411696466)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 7.819590e-01
#   2 SNES Function norm 2.014196e-01
#   3 SNES Function norm 1.999638e-02
#   4 SNES Function norm 2.220236e-04
#   5 SNES Function norm 2.809736e-08
#   6 SNES Function norm 3.928131e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 30 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.42108924930619, 5.990820531461324)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358801e+00
#   2 SNES Function norm 1.172335e+00
#   3 SNES Function norm 7.533126e-01
#   4 SNES Function norm 2.404174e-01
#   5 SNES Function norm 2.852449e-02
#   6 SNES Function norm 4.911204e-04
#   7 SNES Function norm 1.462920e-07
#   8 SNES Function norm 1.353044e-14
# PETSc SNES solver converged in 8 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 31 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (9.210917959140161, 3.5290287686898445)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 7.452983e-01
#   2 SNES Function norm 1.730384e-01
#   3 SNES Function norm 1.348275e-02
#   4 SNES Function norm 9.013660e-05
#   5 SNES Function norm 4.106171e-09
#   6 SNES Function norm 4.175045e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 32 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (0.4717795689316696, 2.117885608637253)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.581683e-02
#   2 SNES Function norm 2.341700e-05
#   3 SNES Function norm 4.904147e-11
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 33 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.884368272303824, 3.128980724016081)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.201990e-01
#   2 SNES Function norm 2.319662e-02
#   3 SNES Function norm 2.507946e-04
#   4 SNES Function norm 2.902960e-08
#   5 SNES Function norm 4.285886e-15
# PETSc SNES solver converged in 5 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 34 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.353050069679084, 2.2873042234064935)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 5.142862e-02
#   2 SNES Function norm 6.392551e-04
#   3 SNES Function norm 9.036783e-08
#   4 SNES Function norm 4.701143e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 35 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.2471781165731985, 2.171770159922259)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.033387e-01
#   2 SNES Function norm 3.339389e-03
#   3 SNES Function norm 3.354022e-06
#   4 SNES Function norm 3.391366e-12
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 36 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.399268009801524, 0.9485243440512099)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 6.519442e-02
#   2 SNES Function norm 4.946856e-04
#   3 SNES Function norm 4.297308e-08
#   4 SNES Function norm 3.850858e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 37 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.192800107396921, 5.033550534856877)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 9.857722e-01
#   2 SNES Function norm 2.934282e-01
#   3 SNES Function norm 4.409227e-02
#   4 SNES Function norm 1.220539e-03
#   5 SNES Function norm 9.865930e-07
#   6 SNES Function norm 6.547674e-13
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 38 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.8237208853134295, 7.725070832132917)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358904e+00
#   2 SNES Function norm 1.221271e+00
#   3 SNES Function norm 1.096780e+00
#   4 SNES Function norm 9.755710e-01
#   5 SNES Function norm 6.883847e-01
#   6 SNES Function norm 2.929858e-01
#   7 SNES Function norm 4.284731e-02
#   8 SNES Function norm 1.218062e-03
#   9 SNES Function norm 1.010541e-06
#   10 SNES Function norm 6.827690e-13
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 39 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (0.5186903061428015, 4.807554493700712)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.116032e-01
#   2 SNES Function norm 3.017023e-02
#   3 SNES Function norm 5.946155e-04
#   4 SNES Function norm 2.276211e-07
#   5 SNES Function norm 3.374274e-14
# PETSc SNES solver converged in 5 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 40 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (5.1780177864022425, 4.76955328968957)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.500195e+00
#   2 SNES Function norm 4.724672e-01
#   3 SNES Function norm 8.952998e-02
#   4 SNES Function norm 4.357806e-03
#   5 SNES Function norm 1.126613e-05
#   6 SNES Function norm 7.699327e-11
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 41 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.71001992579939, 7.09957732239061)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358894e+00
#   2 SNES Function norm 1.221341e+00
#   3 SNES Function norm 1.097030e+00
#   4 SNES Function norm 8.797264e-01
#   5 SNES Function norm 7.416406e-01
#   6 SNES Function norm 1.781236e-01
#   7 SNES Function norm 1.717629e-02
#   8 SNES Function norm 1.889679e-04
#   9 SNES Function norm 2.309524e-08
#   10 SNES Function norm 4.017029e-15
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 42 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.338619674347967, 0.9459471283468279)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 3.728944e-02
#   2 SNES Function norm 1.224716e-04
#   3 SNES Function norm 1.990464e-09
#   4 SNES Function norm 4.289014e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 43 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.8760170676300203, 0.7128173505299883)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.411605e-02
#   2 SNES Function norm 3.171032e-05
#   3 SNES Function norm 9.736884e-11
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 44 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.4182701203755474, 3.9533656870229197)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 9.317325e-01
#   2 SNES Function norm 2.474887e-01
#   3 SNES Function norm 2.766266e-02
#   4 SNES Function norm 4.017643e-04
#   5 SNES Function norm 8.747996e-08
#   6 SNES Function norm 5.869263e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 45 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.869136713345385, 2.4926870388950495)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.608830e-01
#   2 SNES Function norm 1.008483e-02
#   3 SNES Function norm 3.816905e-05
#   4 SNES Function norm 5.447154e-10
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 46 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.865560332256991, 5.3734777375909815)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 8.154685e-01
#   2 SNES Function norm 3.028546e-01
#   3 SNES Function norm 4.719974e-02
#   4 SNES Function norm 1.432551e-03
#   5 SNES Function norm 1.364456e-06
#   6 SNES Function norm 1.241614e-12
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 47 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.3187648297905068, 8.013986981231454)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.359289e+00
#   2 SNES Function norm 1.222529e+00
#   3 SNES Function norm 1.098941e+00
#   4 SNES Function norm 9.873269e-01
#   5 SNES Function norm 8.529939e-01
#   6 SNES Function norm 5.439087e-01
#   7 SNES Function norm 1.626816e-01
#   8 SNES Function norm 1.719102e-02
#   9 SNES Function norm 2.276981e-04
#   10 SNES Function norm 3.955822e-08
#   11 SNES Function norm 4.422967e-15
# PETSc SNES solver converged in 11 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 48 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.25440233695105, 1.1579093926212656)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 4.750915e-02
#   2 SNES Function norm 2.707187e-04
#   3 SNES Function norm 1.168018e-08
#   4 SNES Function norm 4.333081e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 49 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.5680807560775567, 8.506707040785505)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.359002e+00
#   2 SNES Function norm 1.221474e+00
#   3 SNES Function norm 1.096935e+00
#   4 SNES Function norm 9.845510e-01
#   5 SNES Function norm 8.409614e-01
#   6 SNES Function norm 4.350600e-01
#   7 SNES Function norm 4.908304e-02
#   8 SNES Function norm 1.750385e-03
#   9 SNES Function norm 2.295835e-06
#   10 SNES Function norm 3.800908e-12
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 50 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (5.892274131908236, 2.3880701056550953)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.069721e-01
#   2 SNES Function norm 1.596417e-02
#   3 SNES Function norm 9.727514e-05
#   4 SNES Function norm 3.624486e-09
#   5 SNES Function norm 3.834802e-15
# PETSc SNES solver converged in 5 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 51 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.328312516115321, 9.220167913559784)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358533e+00
#   2 SNES Function norm 1.219930e+00
#   3 SNES Function norm 1.094357e+00
#   4 SNES Function norm 9.814453e-01
#   5 SNES Function norm 7.936198e-01
#   6 SNES Function norm 5.948912e-01
#   7 SNES Function norm 1.264133e-01
#   8 SNES Function norm 9.306905e-03
#   9 SNES Function norm 5.770920e-05
#   10 SNES Function norm 2.193389e-09
#   11 SNES Function norm 3.988983e-15
# PETSc SNES solver converged in 11 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 52 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.723929085240882, 0.5801824721206043)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 2.285952e-02
#   2 SNES Function norm 2.436898e-05
#   3 SNES Function norm 5.412386e-11
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 53 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.8696270940714832, 2.644707112811533)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 9.660781e-02
#   2 SNES Function norm 3.496259e-03
#   3 SNES Function norm 4.074046e-06
#   4 SNES Function norm 5.468084e-12
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 54 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.269069106529332, 0.8294295829407184)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 3.135683e-02
#   2 SNES Function norm 7.051324e-05
#   3 SNES Function norm 5.813129e-10
# PETSc SNES solver converged in 3 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 55 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (6.827757527609915, 9.639150363160585)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.357947e+00
#   2 SNES Function norm 1.218374e+00
#   3 SNES Function norm 1.092234e+00
#   4 SNES Function norm 9.792888e-01
#   5 SNES Function norm 7.040958e-01
#   6 SNES Function norm 2.780847e-01
#   7 SNES Function norm 3.684772e-02
#   8 SNES Function norm 8.669522e-04
#   9 SNES Function norm 4.924384e-07
#   10 SNES Function norm 1.549510e-13
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 56 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.101712167065171, 7.93616169876208)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358306e+00
#   2 SNES Function norm 1.219741e+00
#   3 SNES Function norm 1.094607e+00
#   4 SNES Function norm 8.999667e-01
#   5 SNES Function norm 7.700758e-01
#   6 SNES Function norm 1.798846e-01
#   7 SNES Function norm 1.672860e-02
#   8 SNES Function norm 1.720186e-04
#   9 SNES Function norm 1.819422e-08
#   10 SNES Function norm 4.303663e-15
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 57 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.590237610784971, 9.668821557270444)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.357804e+00
#   2 SNES Function norm 1.218068e+00
#   3 SNES Function norm 1.091890e+00
#   4 SNES Function norm 9.789916e-01
#   5 SNES Function norm 6.771334e-01
#   6 SNES Function norm 2.233184e-01
#   7 SNES Function norm 2.518552e-02
#   8 SNES Function norm 4.089480e-04
#   9 SNES Function norm 1.089045e-07
#   10 SNES Function norm 8.507847e-15
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 58 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.898159802965819, 4.3236296658651785)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.325587e+00
#   2 SNES Function norm 3.944758e-01
#   3 SNES Function norm 6.306166e-02
#   4 SNES Function norm 2.066231e-03
#   5 SNES Function norm 2.358057e-06
#   6 SNES Function norm 3.123062e-12
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# ::::::::::::::::::::::::::::::::::: DEIM 59 ::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.9591842038239207, 7.863025093841698)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.359184e+00
#   2 SNES Function norm 1.222158e+00
#   3 SNES Function norm 1.098259e+00
#   4 SNES Function norm 9.864093e-01
#   5 SNES Function norm 8.132003e-01
#   6 SNES Function norm 3.587324e-01
#   7 SNES Function norm 2.202513e-02
#   8 SNES Function norm 3.829597e-04
#   9 SNES Function norm 1.138144e-07
#   10 SNES Function norm 1.050412e-14
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# ================================================================================
# =                      DEIM preprocessing phase ends for                       =
# =   { v_0 * (-1 + exp(f_9 * f_14)) / f_14 } * dx(<Mesh #0>[everywhere], {}),   =
# =                                    where                                     =
# =                                 f_14 = mu_1                                  =
# =f_9 = solution of NonlinearEllipticDEIM (exact problem decorator: False, component: (None,))=
# =               with id 49fc90be369b6ead57691b159f98bb7ecf8d1031               =
# ================================================================================
#
# ================================================================================
# =                        DEIM offline phase begins for                         =
# =   { v_0 * (-1 + exp(f_9 * f_14)) / f_14 } * dx(<Mesh #0>[everywhere], {}),   =
# =                                    where                                     =
# =                                 f_14 = mu_1                                  =
# =f_9 = solution of NonlinearEllipticDEIM (exact problem decorator: False, component: (None,))=
# =               with id 49fc90be369b6ead57691b159f98bb7ecf8d1031               =
# ================================================================================
# find initial mu
# initial maximum interpolation error = 0.12563364123789508
# initial maximum interpolation relative error = 1.0
#
# :::::::::::::::::::::::::::::::::: DEIM N = 0 ::::::::::::::::::::::::::::::::::
# solve interpolation for mu = (0.2969488703196016, 6.385801888346545)
# compute and locate maximum interpolation error
# update locations with (605,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cbd121815852> in <module>
#       1 reduction_method.initialize_training_set(50, DEIM=60)
# ----> 2 reduced_problem = reduction_method.offline()
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/deim_decorated_reduction_method.py in offline(self)
#     130             for (term, DEIM_reductions_term) in self.DEIM_reductions.items():
#     131                 for (_, DEIM_reduction_term_q) in DEIM_reductions_term.items():
# --> 132                     DEIM_reduction_term_q.offline()
#     133             self.truth_problem.set_mu(lifting_mu)
#     134             return DifferentialProblemReductionMethod_DerivedClass.offline(self)
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in offline(self)
#      56         need_to_do_offline_stage = self._init_offline()
#      57         if need_to_do_offline_stage:
# ---> 58             self._offline()
#      59         self._finalize_offline()
#      60         return self.EIM_approximation
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/decorators/snapshot_links_to_cache.py in patched_offline_method(self_)
#      73
#      74         # Call standard offline
# ---> 75         reduced_problem = offline_method(self_)
#      76
#      77         # Disable patch
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in _offline(self)
#     141
#     142                 print("update locations with", maximum_location)
# --> 143                 self.update_interpolation_locations(maximum_location)
#     144
#     145                 print("update basis")
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in update_interpolation_locations(self, maximum_location)
#     215
#     216     def update_interpolation_locations(self, maximum_location):
# --> 217         self.EIM_approximation.interpolation_locations.append(maximum_location)
#     218         self.EIM_approximation.interpolation_locations.save(
#     219             self.EIM_approximation.folder["reduced_operators"], "interpolation_locations")
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/reduced_mesh.py in append(self, global_dofs)
#     230                 assert global_dof_found == 1
#     231             # Actually update to data structures using updated cells marker
# --> 232             self._update()
#     233
#     234         def _update(self):
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/reduced_mesh.py in _update(self)
#     235             N = self._get_next_index()
#     236             # Create submesh
# --> 237             reduced_mesh = wrapping.create_submesh(self.mesh, self.reduced_mesh_markers[N])
#     238             self.reduced_mesh[N] = reduced_mesh
#     239             # Create subdomain data on submesh
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/wrapping/create_submesh.py in create_submesh(mesh, markers)
#     226     """
#     227     initialize_global_indices = compile_cpp_code(cpp_code).initialize_global_indices
# --> 228     initialize_global_indices(mesh, mesh.topology().dim() - 1)
#     229     # Prepare global indices of facets
#     230     mesh_facets_local_to_global_indices = dict()
#
# TypeError: initialize_global_indices(): incompatible function arguments. The following argument types are supported:
#     1. (arg0: dolfin::Mesh, arg1: int) -> None
#
# Invoked with: <dolfin.cpp.mesh.Mesh object at 0x7f3b78f5df10>, 1

# %% [markdown]
# ### 4.6. Perform an online solve

# %%
online_mu = (0.3, 9.0)
reduced_problem.set_mu(online_mu)
reduced_solution = reduced_problem.solve()
plot(reduced_solution, reduced_problem=reduced_problem)

# %% [markdown]
# ### 4.7. Perform an error analysis

# %%
reduction_method.initialize_testing_set(50, DEIM=60)
reduction_method.error_analysis()

# %% [markdown]
# ### 4.8. Perform a speedup analysis

# %%
reduction_method.speedup_analysis()
