# %% [markdown]
# ## Tutorial 07 - Non linear Elliptic problem
# **_Keywords: EIM, POD-Galerkin_**
#
# ### 1. Introduction
#
# In this tutorial, we consider a non linear elliptic problem in a two-dimensional spatial domain $\Omega=(0,1)^2$. We impose a homogeneous Dirichlet condition on the boundary $\partial\Omega$. The source term is characterized by the following expression
# $$
# g(\boldsymbol{x}; \boldsymbol{\mu}) = 100\sin(2\pi x_0)cos(2\pi x_1) \quad \forall \boldsymbol{x} = (x_0, x_1) \in \Omega.
# $$
#
# This problem is characterized by two parameters. The first parameter $\mu_0$ controls the strength of the sink term and the second parameter $\mu_1$ the strength of the nonlinearity. The range of the two parameters is the following:
# $$
# \mu_0,\mu_1\in[0.01,10.0]
# $$
# The parameter vector $\boldsymbol{\mu}$ is thus given by
# $$
# \boldsymbol{\mu} = (\mu_0,\mu_1)
# $$
# on the parameter domain
# $$
# \mathbb{P}=[0.01,10]^2.
# $$
#
#
# In order to obtain a faster approximation of the problem, we pursue a model reduction by means of a POD-Galerkin reduced order method. In order to preserve the affinity assumption empirical interpolation method will be used on the forcing term $g(\boldsymbol{x}; \boldsymbol{\mu})$.

# %% [markdown]
# ### 2. Parametrized formulation
#
# Let $u(\boldsymbol{\mu})$ be the solution in the domain $\Omega$.
#
# The strong formulation of the parametrized problem is given by:
# <center>for a given parameter $\boldsymbol{\mu}\in\mathbb{P}$, find $u(\boldsymbol{\mu})$ such that</center>
#
# $$ -\nabla^2u(\boldsymbol{\mu})+\frac{\mu_0}{\mu_1}(\exp\{\mu_1u(\boldsymbol{\mu})\}-1)=g(\boldsymbol{x}; \boldsymbol{\mu})$$
# <br>
#
# The corresponding weak formulation reads:
# <center>for a given parameter $\boldsymbol{\mu}\in\mathbb{P}$, find $u(\boldsymbol{\mu})\in\mathbb{V}$ such that</center>
#
# $$a\left(u(\boldsymbol{\mu}),v;\boldsymbol{\mu}\right)+c\left(u(\boldsymbol{\mu}),v;\boldsymbol{\mu}\right)=f(v;\boldsymbol{\mu})\quad \forall v\in\mathbb{V}$$
#
# where
#
# * the function space $\mathbb{V}$ is defined as
# $$
# \mathbb{V} = \{v\in H_1(\Omega) : v|_{\partial\Omega}=0\}
# $$
# * the parametrized bilinear form $a(\cdot, \cdot; \boldsymbol{\mu}): \mathbb{V} \times \mathbb{V} \to \mathbb{R}$ is defined by
# $$a(u, v;\boldsymbol{\mu})=\int_{\Omega} \nabla u\cdot \nabla v \ d\boldsymbol{x},$$
# * the parametrized bilinear form $c(\cdot, \cdot; \boldsymbol{\mu}): \mathbb{V} \times \mathbb{V} \to \mathbb{R}$ is defined by
# $$c(u, v;\boldsymbol{\mu})=\mu_0\int_{\Omega} \frac{1}{\mu_1}\big(\exp\{\mu_1u\} - 1\big)v \ d\boldsymbol{x},$$
# * the parametrized linear form $f(\cdot; \boldsymbol{\mu}): \mathbb{V} \to \mathbb{R}$ is defined by
# $$f(v; \boldsymbol{\mu})= \int_{\Omega}g(\boldsymbol{x}; \boldsymbol{\mu})v \ d\boldsymbol{x}.$$
#
# The output of interest $s(\boldsymbol{\mu})$ is given by
# $$s(\boldsymbol{\mu}) = \int_{\Omega} v \ d\boldsymbol{x}$$
# is computed for each $\boldsymbol{\mu}$.

# %%
from dolfin import *
from rbnics import *

# %% [markdown]
# ### 3. Affine Decomposition
#
# For this problem the affine decomposition is straightforward:
# $$a(u,v;\boldsymbol{\mu})=\underbrace{1}_{\Theta^{a}_0(\boldsymbol{\mu})}\underbrace{\int_{\Omega}\nabla u \cdot \nabla v \ d\boldsymbol{x}}_{a_0(u,v)},$$
# $$c(u,v;\boldsymbol{\mu})=\underbrace{\mu_0}_{\Theta^{c}_0(\boldsymbol{\mu})}\underbrace{\int_{\Omega}\frac{1}{\mu_1}\big(\exp\{\mu_1u\} - 1\big)v \ d\boldsymbol{x}}_{c_0(u,v)},$$
# $$f(v; \boldsymbol{\mu}) = \underbrace{100}_{\Theta^{f}_0(\boldsymbol{\mu})} \underbrace{\int_{\Omega}\sin(2\pi x_0)cos(2\pi x_1)v \ d\boldsymbol{x}}_{f_0(v)}.$$
# We will implement the numerical discretization of the problem in the class
# ```
# class NonlinearElliptic(NonlinearEllipticProblem):
# ```
# by specifying the coefficients $\Theta^{a}_*(\boldsymbol{\mu})$, $\Theta^{c}_*(\boldsymbol{\mu})$ and $\Theta^{f}_*(\boldsymbol{\mu})$ in the method
# ```
#     def compute_theta(self, term):
# ```
# and the bilinear forms $a_*(u, v)$, $c_*(u, v)$ and linear forms $f_*(v)$ in
# ```
#     def assemble_operator(self, term):
# ```

# %%
@EIM("online")
@ExactParametrizedFunctions("offline")
class NonlinearElliptic(NonlinearEllipticProblem):

    # Default initialization of members
    def __init__(self, V, **kwargs):
        # Call the standard initialization
        NonlinearEllipticProblem.__init__(self, V, **kwargs)
        # ... and also store FEniCS data structures for assembly
        assert "subdomains" in kwargs
        assert "boundaries" in kwargs
        self.subdomains, self.boundaries = kwargs["subdomains"], kwargs["boundaries"]
        self.du = TrialFunction(V)
        self.u = self._solution
        self.v = TestFunction(V)
        self.dx = Measure("dx")(subdomain_data=self.subdomains)
        self.ds = Measure("ds")(subdomain_data=self.boundaries)
        # Store the forcing term expression
        self.f = Expression("sin(2*pi*x[0])*sin(2*pi*x[1])", element=self.V.ufl_element())
        # Customize nonlinear solver parameters
        self._nonlinear_solver_parameters.update({
            "linear_solver": "mumps",
            "maximum_iterations": 20,
            "report": True
        })

    # Return custom problem name
    def name(self):
        return "NonlinearEllipticEIM"

    # Return theta multiplicative terms of the affine expansion of the problem.
    @compute_theta_for_derivatives
    def compute_theta(self, term):
        mu = self.mu
        if term == "a":
            theta_a0 = 1.
            return (theta_a0,)
        elif term == "c":
            theta_c0 = mu[0]
            return (theta_c0,)
        elif term == "f":
            theta_f0 = 100.
            return (theta_f0,)
        elif term == "s":
            theta_s0 = 1.0
            return (theta_s0,)
        else:
            raise ValueError("Invalid term for compute_theta().")

    # Return forms resulting from the discretization of the affine expansion of the problem operators.
    def assemble_operator(self, term):
        v = self.v
        dx = self.dx
        if term == "a":
            du = self.du
            a0 = inner(grad(du), grad(v)) * dx
            return (a0,)
        elif term == "c":
            u = self.u
            mu = self.mu
            c0 = (exp(mu[1] * u) - 1) / mu[1] * v * dx
            return (c0,)
        elif term == "dc":  # preferred over derivative() computation which does not cancel out trivial mu[1] factors
            du = self.du
            u = self.u
            mu = self.mu
            dc0 = exp(mu[1] * u) * du * v * dx
            return (dc0,)
        elif term == "f":
            f = self.f
            f0 = f * v * dx
            return (f0,)
        elif term == "s":
            s0 = v * dx
            return (s0,)
        elif term == "dirichlet_bc":
            bc0 = [DirichletBC(self.V, Constant(0.0), self.boundaries, 1)]
            return (bc0,)
        elif term == "inner_product":
            du = self.du
            x0 = inner(grad(du), grad(v)) * dx
            return (x0,)
        else:
            raise ValueError("Invalid term for assemble_operator().")


# Customize the resulting reduced problem
@CustomizeReducedProblemFor(NonlinearEllipticProblem)
def CustomizeReducedNonlinearElliptic(ReducedNonlinearElliptic_Base):
    class ReducedNonlinearElliptic(ReducedNonlinearElliptic_Base):
        def __init__(self, truth_problem, **kwargs):
            ReducedNonlinearElliptic_Base.__init__(self, truth_problem, **kwargs)
            self._nonlinear_solver_parameters.update({
                "report": True,
                "line_search": "wolfe"
            })

    return ReducedNonlinearElliptic

# %% [markdown]
# ## 4. Main program
#
# ### 4.1. Read the mesh for this problem
# The mesh was generated by the [data/generate_mesh.ipynb](data/generate_mesh.ipynb) notebook.

# %%
mesh = Mesh("data/square.xml")
subdomains = MeshFunction("size_t", mesh, "data/square_physical_region.xml")
boundaries = MeshFunction("size_t", mesh, "data/square_facet_region.xml")

# %% [markdown]
# ### 4.2. Create Finite Element space (Lagrange P1)

# %%
V = FunctionSpace(mesh, "Lagrange", 1)

# %% [markdown]
# ### 4.3. Allocate an object of the NonlinearElliptic class

# %%
problem = NonlinearElliptic(V, subdomains=subdomains, boundaries=boundaries)
mu_range = [(0.01, 10.0), (0.01, 10.0)]
problem.set_mu_range(mu_range)

# %% [markdown]
# ### 4.4. Prepare reduction with a POD-Galerkin method

# %%
reduction_method = PODGalerkin(problem)
reduction_method.set_Nmax(20, EIM=21)
reduction_method.set_tolerance(1e-8, EIM=1e-4)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %% [markdown]
# ### 4.5. Perform the offline phase

# %%
reduction_method.initialize_training_set(50, EIM=10)
reduced_problem = reduction_method.offline()
# Out:
# ================================================================================
# =                      EIM preprocessing phase begins for                      =
# =                     (-1 + exp(f_9 * f_14)) * 1.0 / f_14,                     =
# =                                    where                                     =
# =                                 f_14 = mu_1                                  =
# =f_9 = solution of NonlinearEllipticEIM (exact problem decorator: False, component: (None,))=
# =               with id 2a1d1ccf0b90d1b20f752208e38ed6a73b2bf22d               =
# ================================================================================
#
# :::::::::::::::::::::::::::::::::::: EIM 0 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (7.703404042471355, 7.864153296684836)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358372e+00
#   2 SNES Function norm 1.219902e+00
#   3 SNES Function norm 1.094829e+00
#   4 SNES Function norm 9.025487e-01
#   5 SNES Function norm 7.919375e-01
#   6 SNES Function norm 1.878591e-01
#   7 SNES Function norm 1.814631e-02
#   8 SNES Function norm 2.027171e-04
#   9 SNES Function norm 2.536709e-08
#   10 SNES Function norm 3.890748e-15
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 1 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (1.3726746953027664, 2.8850130381788808)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 9.012807e-02
#   2 SNES Function norm 3.252648e-03
#   3 SNES Function norm 3.658561e-06
#   4 SNES Function norm 4.554085e-12
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 2 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (6.448701170525578, 9.172335566103076)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358159e+00
#   2 SNES Function norm 1.219009e+00
#   3 SNES Function norm 1.093191e+00
#   4 SNES Function norm 9.803635e-01
#   5 SNES Function norm 7.027177e-01
#   6 SNES Function norm 2.800588e-01
#   7 SNES Function norm 3.759114e-02
#   8 SNES Function norm 9.051361e-04
#   9 SNES Function norm 5.375406e-07
#   10 SNES Function norm 1.848020e-13
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 3 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.6783814603065923, 7.3225257360392595)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.359125e+00
#   2 SNES Function norm 1.222005e+00
#   3 SNES Function norm 1.098068e+00
#   4 SNES Function norm 9.481376e-01
#   5 SNES Function norm 6.084100e-01
#   6 SNES Function norm 1.896022e-01
#   7 SNES Function norm 2.118035e-02
#   8 SNES Function norm 3.185162e-04
#   9 SNES Function norm 7.180542e-08
#   10 SNES Function norm 5.718407e-15
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 4 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (2.476634382500271, 1.4710067882795774)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 4.100807e-02
#   2 SNES Function norm 2.285265e-04
#   3 SNES Function norm 8.111229e-09
#   4 SNES Function norm 4.506223e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 5 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.619578110112, 3.787586672326672)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 8.881660e-01
#   2 SNES Function norm 2.271138e-01
#   3 SNES Function norm 2.299791e-02
#   4 SNES Function norm 2.699386e-04
#   5 SNES Function norm 3.821299e-08
#   6 SNES Function norm 4.039208e-15
# PETSc SNES solver converged in 6 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 6 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (3.066434948845556, 8.68716526999748)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.358880e+00
#   2 SNES Function norm 1.221055e+00
#   3 SNES Function norm 1.096202e+00
#   4 SNES Function norm 9.836276e-01
#   5 SNES Function norm 8.279550e-01
#   6 SNES Function norm 3.674075e-01
#   7 SNES Function norm 2.015754e-02
#   8 SNES Function norm 3.048658e-04
#   9 SNES Function norm 6.923859e-08
#   10 SNES Function norm 5.405963e-15
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 7 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (0.3096103293545913, 8.229670854675916)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.331717e+00
#   2 SNES Function norm 1.184904e+00
#   3 SNES Function norm 1.049768e+00
#   4 SNES Function norm 9.053968e-01
#   5 SNES Function norm 7.104220e-01
#   6 SNES Function norm 3.283138e-01
#   7 SNES Function norm 3.206804e-02
#   8 SNES Function norm 9.765394e-04
#   9 SNES Function norm 8.855741e-07
#   10 SNES Function norm 6.959391e-13
# PETSc SNES solver converged in 10 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 8 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (4.527740431347839, 5.305144281507872)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 1.022623e+00
#   2 SNES Function norm 6.525475e-01
#   3 SNES Function norm 1.524966e-01
#   4 SNES Function norm 1.267082e-02
#   5 SNES Function norm 9.909307e-05
#   6 SNES Function norm 6.171867e-09
#   7 SNES Function norm 4.071868e-15
# PETSc SNES solver converged in 7 iterations with convergence reason 2.
# add to snapshots
#
# :::::::::::::::::::::::::::::::::::: EIM 9 :::::::::::::::::::::::::::::::::::::
# evaluate parametrized expression at mu = (8.319967394493565, 1.0683349257443995)
#   0 SNES Function norm 1.510614e+00
#   1 SNES Function norm 7.501250e-02
#   2 SNES Function norm 7.704538e-04
#   3 SNES Function norm 1.147040e-07
#   4 SNES Function norm 4.728015e-15
# PETSc SNES solver converged in 4 iterations with convergence reason 2.
# add to snapshots
#
# ================================================================================
# =                       EIM preprocessing phase ends for                       =
# =                     (-1 + exp(f_9 * f_14)) * 1.0 / f_14,                     =
# =                                    where                                     =
# =                                 f_14 = mu_1                                  =
# =f_9 = solution of NonlinearEllipticEIM (exact problem decorator: False, component: (None,))=
# =               with id 2a1d1ccf0b90d1b20f752208e38ed6a73b2bf22d               =
# ================================================================================
#
# ================================================================================
# =                         EIM offline phase begins for                         =
# =                     (-1 + exp(f_9 * f_14)) * 1.0 / f_14,                     =
# =                                    where                                     =
# =                                 f_14 = mu_1                                  =
# =f_9 = solution of NonlinearEllipticEIM (exact problem decorator: False, component: (None,))=
# =               with id 2a1d1ccf0b90d1b20f752208e38ed6a73b2bf22d               =
# ================================================================================
#
# find initial mu
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/cache/cache.py in wrapper(*args)
#     181         try:
# --> 182             return storage[args]
#     183         except KeyError:
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/cache/cache.py in __getitem__(self, key)
#     102                            + " and kwargs = " + str(kwargs) + ") from cache")
# --> 103                 raise key_error
#     104         else:
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/cache/cache.py in __getitem__(self, key)
#      82         try:
# ---> 83             storage_value = self._storage[storage_key]
#      84         except KeyError as key_error:
#
# KeyError: FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 0), FiniteElement('Discontinuous Lagrange', triangle, 1))
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-097d2d201958> in <module>
#       1 reduction_method.initialize_training_set(50, EIM=10)
# ----> 2 reduced_problem = reduction_method.offline()
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_decorated_reduction_method.py in offline(self)
#     127             lifting_mu = self.truth_problem.mu
#     128             for (coeff, EIM_reduction_coeff) in self.EIM_reductions.items():
# --> 129                 EIM_reduction_coeff.offline()
#     130             self.truth_problem.set_mu(lifting_mu)
#     131             return DifferentialProblemReductionMethod_DerivedClass.offline(self)
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in offline(self)
#      56         need_to_do_offline_stage = self._init_offline()
#      57         if need_to_do_offline_stage:
# ---> 58             self._offline()
#      59         self._finalize_offline()
#      60         return self.EIM_approximation
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/decorators/snapshot_links_to_cache.py in patched_offline_method(self_)
#      73
#      74         # Call standard offline
# ---> 75         reduced_problem = offline_method(self_)
#      76
#      77         # Disable patch
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in _offline(self)
#     123         if self.EIM_approximation.basis_generation == "Greedy":
#     124             # Initialize first parameter to be used
# --> 125             (error_max, relative_error_max) = self.greedy()
#     126             print("initial maximum interpolation error =", error_max)
#     127             print("initial maximum interpolation relative error =", relative_error_max)
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in greedy(self)
#     265         else:
#     266             print("find next mu")
# --> 267         (error_max, error_argmax) = self.training_set.max(solve_and_computer_error)
#     268         self.EIM_approximation.set_mu(self.training_set[error_argmax])
#     269         self.greedy_selected_parameters.append(self.training_set[error_argmax])
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/sampling/parameter_space_subset.py in max(self, generator, postprocessor)
#      62         values_with_postprocessing = array(len(local_list_indices))
#      63         for i in range(len(local_list_indices)):
# ---> 64             values[i] = generator(self._list[local_list_indices[i]])
#      65             values_with_postprocessing[i] = postprocessor(values[i])
#      66         if self.distributed_max:
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/reduction_methods/eim_approximation_reduction_method.py in solve_and_computer_error(mu)
#     258             self.EIM_approximation.solve()
#     259             self.EIM_approximation.snapshot = self.load_snapshot()
# --> 260             (_, maximum_error, _) = self.EIM_approximation.compute_maximum_interpolation_error()
#     261             return abs(maximum_error)
#     262
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/eim/problems/eim_approximation.py in compute_maximum_interpolation_error(self, N)
#     163
#     164         # Get the location of the maximum error
# --> 165         (maximum_error, maximum_location) = max(abs(error))
#     166
#     167         # Return
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/decorators/dispatch.py in __call__(self, *args, **kwargs)
#     148     def __call__(self, *args, **kwargs):
#     149         func = self._get_func(*args)
# --> 150         return func(*args, **kwargs)
#     151
#     152     def _get_func(self, *args):
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/abs.py in abs(expression)
#      20 @backend_for("dolfin", inputs=((Matrix.Type(), Vector.Type(), Function.Type(), Operator), ))
#      21 def abs(expression):
# ---> 22     return _abs(expression)
#      23
#      24
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/decorators/dispatch.py in __call__(self, *args, **kwargs)
#     148     def __call__(self, *args, **kwargs):
#     149         func = self._get_func(*args)
# --> 150         return func(*args, **kwargs)
#     151
#     152     def _get_func(self, *args):
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/abs.py in _abs(expression)
#      76     global_dof_max = global_dof_max[0]
#      77     coordinates_max = get_global_dof_coordinates(global_dof_max, space)
# ---> 78     component_max = get_global_dof_component(global_dof_max, space)
#      79     # Prettify print
#      80     coordinates_max_component_max_dof_max = PrettyTuple(coordinates_max, component_max, global_dof_max)
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/wrapping/get_global_dof_component.py in get_global_dof_component(global_dof, V, global_to_local, local_dof_to_component)
#      14         global_to_local = get_global_dof_to_local_dof_map(V, V.dofmap())
#      15     if local_dof_to_component is None:
# ---> 16         local_dof_to_component = get_local_dof_to_component_map(V)
#      17
#      18     mpi_comm = V.mesh().mpi_comm()
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/utils/cache/cache.py in wrapper(*args)
#     182             return storage[args]
#     183         except KeyError:
# --> 184             storage[args] = fun(*args)
#     185             return storage[args]
#     186
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/wrapping/get_local_dof_to_component_map.py in get_local_dof_to_component_map(V)
#      11 @cache
#      12 def get_local_dof_to_component_map(V):
# ---> 13     return _get_local_dof_to_component_map(V)
#      14
#      15
#
# /usr/local/lib/python3.6/dist-packages/RBniCS-0.1.dev1-py3.6.egg/rbnics/backends/dolfin/wrapping/get_local_dof_to_component_map.py in _get_local_dof_to_component_map(V, component, dof_component_map, recursive)
#      49         """
#      50         collapse_dofmap = compile_cpp_code(cpp_code).collapse_dofmap
# ---> 51         collapsed_dofs = collapse_dofmap(V.dofmap(), V.mesh())
#      52         component[0] += 1
#      53         for collapsed_dof in collapsed_dofs:
#
# TypeError: collapse_dofmap(): incompatible function arguments. The following argument types are supported:
#     1. (arg0: dolfin::DofMap, arg1: dolfin::Mesh) -> List[int]
#
# Invoked with: <dolfin.cpp.fem.DofMap object at 0x7fd9889f9d50>, <dolfin.cpp.mesh.Mesh object at 0x7fd98d194c50>

# %% [markdown]
# ### 4.6. Perform an online solve

# %%
online_mu = (0.3, 9.0)
reduced_problem.set_mu(online_mu)
reduced_solution = reduced_problem.solve()
plot(reduced_solution, reduced_problem=reduced_problem)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aa2efc4a7a0f> in <module>
#       1 online_mu = (0.3, 9.0)
# ----> 2 reduced_problem.set_mu(online_mu)
#       3 reduced_solution = reduced_problem.solve()
#       4 plot(reduced_solution, reduced_problem=reduced_problem)
#
# NameError: name 'reduced_problem' is not defined

# %% [markdown]
# ### 4.7. Perform an error analysis

# %%
reduction_method.initialize_testing_set(50, EIM=60)
reduction_method.error_analysis()

# %% [markdown]
# ### 4.8. Perform a speedup analysis

# %%
reduction_method.speedup_analysis()
